# %%
from IPython.display import HTML

import math
import pandas as pd
import numpy as np

from bokeh.plotting import figure, output_notebook, show

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1209">Loading BokehJS ...</span>
#     </div>

# %%
import sys
sys.path.insert(1,'../covid-website')

import SISV as s

# %%
#----------------------------------------------------------
params1 = {
    "population"    : 1e6,
    "i0"            : 1,
    "death_rate"    : 0.5*1e-2,
    "detection_rate": 10e-2,
    "gamma"         : 1/6,
    "gamma_crit"    : 1/35,
    "crit_stages"   : 1,
    "gamma_pos"     : 1/5,
    "immun"         : 0,
    "vacc_start"    : 365,
    "vacc_rate"     : 0.3/365,  #30% of population per year
    "vacc_immun"    : 1/180,
    
    "interv"        : 'piecewise linear',
    "init_beta"     : '',
    'segments'      : 1,
    "beta0"         : 2/6,
    "t1"            : 30,
    "beta1"         : 0.5/6
}

params2 = params1.copy()
#params2['gamma_crit'] = 1/35
params2['crit_stages'] = 4

n=300
x = np.arange(n)

y1 = s.SISV(x, params1)
y2 = s.SISV(x, params2)

p = figure(plot_width=800, plot_height=600 , y_axis_type="log")
p.line(x[1:], np.diff(y1[:,s.cF]), line_width=3, line_color='green', line_dash='solid', alpha=0.3)
p.line(x[1:], np.diff(y2[:,s.cF]), line_width=1, line_color='blue', line_dash='solid', alpha=0.3)

#p.line(x, y1[:,s.cF], line_width=3, line_color='green', line_dash='solid', alpha=0.3)
#p.line(x, y2[:,s.cF], line_width=1, line_color='blue', line_dash='solid', alpha=0.3)

show(p)
# Out:
#   <div class="bk-root" id="8e656089-cba5-4ab2-a10d-d2c27657cb26" data-root-id="1210"></div>
